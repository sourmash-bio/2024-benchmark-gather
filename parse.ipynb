# %%
import sys
sys.prefix
# Out:
# '/home/ctbrown/.conda/envs/jup312'

# %%
bench_dir = 'benchmarks-2024-10-12.pr-branch-430'

# %%
ls
# Out:
# README.md                                SRR5650070.gather.csv
# SRR12324253.fastgather.csv               SRR5650070.prefetch.csv
# SRR12324253.fastmultigather.csv          SRR5650070.pygather.csv
# SRR12324253.fastmultigather_rocksdb.csv  SRR5650070.trim.sig.zip
# SRR12324253.gather.csv                   SRR606249.fastgather.csv
# SRR12324253.prefetch.csv                 SRR606249.fastmultigather.csv
# SRR12324253.pygather.csv                 SRR606249.fastmultigather_rocksdb.csv
# SRR12324253.trim.sig.zip                 SRR606249.gather.csv
# SRR1976948.fastgather.csv                SRR606249.prefetch.csv
# SRR1976948.fastmultigather.csv           SRR606249.pygather.csv
# SRR1976948.fastmultigather_rocksdb.csv   SRR606249.trim.sig.zip
# SRR1976948.gather.csv                    Snakefile
# SRR1976948.prefetch.csv                  benchmarks/
# SRR1976948.pygather.csv                  benchmarks-2024-06-30/
# SRR1976948.trim.sig.zip                  benchmarks-2024-08-25.pr-branch-430/
# SRR5650070.fastgather.csv                benchmarks-2024-10-12.pr-branch-430/
# SRR5650070.fastmultigather.csv           gtdb-rs214-k31.rocksdb/
# SRR5650070.fastmultigather_rocksdb.csv   parse.ipynb

# %%
import pandas as pd
import os

# %%
pd.read_csv(f'{bench_dir}/fastmultigather.SRR12324253.txt', sep='\t')
# Out:
#           s    h:m:s   max_rss   max_vms   max_uss   max_pss  io_in  io_out  \
# 0  372.0828  0:06:12  28082.98  33447.48  28104.92  28113.69    0.0    20.7
#
#    mean_load  cpu_time
# 0    1007.05    3753.6

# %%
samples = ['SRR12324253', 'SRR1976948', 'SRR5650070', 'SRR606249']
prefixes = [ 'fastmultigather', 'fastmultigather_rocksdb', 'fastgather', 'pygather']

# %%
df_list = []
for s in samples:
    for p in prefixes:
        df = pd.read_csv(f'{bench_dir}/{p}.{s}.txt', sep='\t')
        df.insert(0, "prefix", [p], True)
        df.insert(1, "sample", [s], True)
        df_list.append(df)

df = pd.concat(df_list)

# %%
df
# Out:
#                     prefix       sample          s    h:m:s   max_rss  \
# 0          fastmultigather  SRR12324253   372.0828  0:06:12  28082.98
# 0  fastmultigather_rocksdb  SRR12324253   101.6996  0:01:41   1322.97
# 0               fastgather  SRR12324253    84.4263  0:01:24   5912.51
# 0                 pygather  SRR12324253  2862.8852  0:47:42  16771.48
# 0          fastmultigather   SRR1976948   467.0326  0:07:47  25236.69
# 0  fastmultigather_rocksdb   SRR1976948   151.3519  0:02:31    590.32
# 0               fastgather   SRR1976948   166.8599  0:02:46   8287.86
# 0                 pygather   SRR1976948  2708.0092  0:45:08  13832.34
# 0          fastmultigather   SRR5650070   303.6404  0:05:03  27227.46
# 0  fastmultigather_rocksdb   SRR5650070   175.7073  0:02:55    812.62
# 0               fastgather   SRR5650070    80.6030  0:01:20   5801.52
# 0                 pygather   SRR5650070  2680.3072  0:44:40  15838.91
# 0          fastmultigather    SRR606249   412.6287  0:06:52  25532.65
# 0  fastmultigather_rocksdb    SRR606249   109.2117  0:01:49    665.67
# 0               fastgather    SRR606249   108.7334  0:01:48   7463.05
# 0                 pygather    SRR606249  2740.8806  0:45:40  14134.77
#
#     max_vms   max_uss   max_pss     io_in  io_out  mean_load  cpu_time
# 0  33447.48  28104.92  28113.69      0.00   20.70    1007.05   3753.60
# 0  16294.63   1314.32   1322.70    829.78    0.00      30.02     37.14
# 0  21167.33   5884.13   5892.54      0.00    0.01    5094.37   4308.37
# 0  21232.03  16759.80  16768.20  11975.12    0.00      99.37   2853.29
# 0  30465.38  25259.37  25268.32      0.12    5.34    1504.12   7035.73
# 0  15566.70    581.09    589.53   1738.59    0.00      28.15     49.11
# 0  21169.81   8303.48   8311.97  12048.56    0.04    3829.14   6396.74
# 0  18300.30  13828.53  13836.88  11973.44    0.00      99.75   2703.34
# 0  32455.97  27252.57  27261.50      0.00   16.80    1199.05   3646.44
# 0  15786.08    803.31    811.81   1931.16    0.00      26.35     51.99
# 0  21161.46   5776.58   5784.96      0.00    0.00    3346.98   2705.63
# 0  20298.81  15826.34  15834.68  11972.32    0.00      99.69   2672.07
# 0  30758.39  25558.80  25567.60      0.00    6.89     959.91   3971.25
# 0  15646.09    661.05    669.46   1129.09    0.00      38.70     49.45
# 0  21235.97   4587.45   4595.86      0.00    0.01    3474.30   3781.99
# 0  18603.15  14128.16  14136.50  11973.44    0.00      99.11   2720.14

# %%
df[df['sample'] == "SRR5650070"]
# Out:
#                     prefix      sample          s    h:m:s   max_rss  \
# 0          fastmultigather  SRR5650070   303.6404  0:05:03  27227.46
# 0  fastmultigather_rocksdb  SRR5650070   175.7073  0:02:55    812.62
# 0               fastgather  SRR5650070    80.6030  0:01:20   5801.52
# 0                 pygather  SRR5650070  2680.3072  0:44:40  15838.91
#
#     max_vms   max_uss   max_pss     io_in  io_out  mean_load  cpu_time
# 0  32455.97  27252.57  27261.50      0.00    16.8    1199.05   3646.44
# 0  15786.08    803.31    811.81   1931.16     0.0      26.35     51.99
# 0  21161.46   5776.58   5784.96      0.00     0.0    3346.98   2705.63
# 0  20298.81  15826.34  15834.68  11972.32     0.0      99.69   2672.07

# %%
df[df['sample'] == "SRR5650070"][["prefix", "s", "max_rss"]]
# Out:
#                     prefix          s   max_rss
# 0          fastmultigather   303.6404  27227.46
# 0  fastmultigather_rocksdb   175.7073    812.62
# 0               fastgather    80.6030   5801.52
# 0                 pygather  2680.3072  15838.91

# %%
x = df[df['sample'] == "SRR5650070"][["prefix", "s", "max_rss"]]
x.set_index("prefix")
# Out:
#                                  s   max_rss
# prefix
# fastmultigather           303.6404  27227.46
# fastmultigather_rocksdb   175.7073    812.62
# fastgather                 80.6030   5801.52
# pygather                 2680.3072  15838.91

# %%
df2 = df.copy()
df2 = df2.sort_values('s')
df2 = df2.set_index(["sample", "prefix"])
df2 = df2[["s", "max_rss"]]

# %%
df2
# Out:
#                                              s   max_rss
# sample      prefix
# SRR5650070  fastgather                 80.6030   5801.52
# SRR12324253 fastgather                 84.4263   5912.51
#             fastmultigather_rocksdb   101.6996   1322.97
# SRR606249   fastgather                108.7334   7463.05
#             fastmultigather_rocksdb   109.2117    665.67
# SRR1976948  fastmultigather_rocksdb   151.3519    590.32
#             fastgather                166.8599   8287.86
# SRR5650070  fastmultigather_rocksdb   175.7073    812.62
#             fastmultigather           303.6404  27227.46
# SRR12324253 fastmultigather           372.0828  28082.98
# SRR606249   fastmultigather           412.6287  25532.65
# SRR1976948  fastmultigather           467.0326  25236.69
# SRR5650070  pygather                 2680.3072  15838.91
# SRR1976948  pygather                 2708.0092  13832.34
# SRR606249   pygather                 2740.8806  14134.77
# SRR12324253 pygather                 2862.8852  16771.48

# %%
ls
# Out:
# README.md                                SRR5650070.gather.csv
# SRR12324253.fastgather.csv               SRR5650070.prefetch.csv
# SRR12324253.fastmultigather.csv          SRR5650070.pygather.csv
# SRR12324253.fastmultigather_rocksdb.csv  SRR5650070.trim.sig.zip
# SRR12324253.gather.csv                   SRR606249.fastgather.csv
# SRR12324253.prefetch.csv                 SRR606249.fastmultigather.csv
# SRR12324253.pygather.csv                 SRR606249.fastmultigather_rocksdb.csv
# SRR12324253.trim.sig.zip                 SRR606249.gather.csv
# SRR1976948.fastgather.csv                SRR606249.prefetch.csv
# SRR1976948.fastmultigather.csv           SRR606249.pygather.csv
# SRR1976948.fastmultigather_rocksdb.csv   SRR606249.trim.sig.zip
# SRR1976948.gather.csv                    Snakefile
# SRR1976948.prefetch.csv                  benchmarks/
# SRR1976948.pygather.csv                  benchmarks-2024-06-30/
# SRR1976948.trim.sig.zip                  benchmarks-2024-08-25.pr-branch-430/
# SRR5650070.fastgather.csv                benchmarks-2024-10-12.pr-branch-430/
# SRR5650070.fastmultigather.csv           gtdb-rs214-k31.rocksdb/
# SRR5650070.fastmultigather_rocksdb.csv   parse.ipynb

# %%
df_by_second = df[df["sample"] == 'SRR1976948'][["prefix", "s", "max_rss"]].sort_values(by="s")
df_by_second.set_index("prefix", inplace=True)
df_by_second
# Out:
#                                  s   max_rss
# prefix
# fastmultigather_rocksdb   151.3519    590.32
# fastgather                166.8599   8287.86
# fastmultigather           467.0326  25236.69
# pygather                 2708.0092  13832.34

# %%
print(df_by_second.to_markdown())
# Out:
# | prefix                  |        s |   max_rss |
# |:------------------------|---------:|----------:|
# | fastmultigather_rocksdb |  151.352 |    590.32 |
# | fastgather              |  166.86  |   8287.86 |
# | fastmultigather         |  467.033 |  25236.7  |
# | pygather                | 2708.01  |  13832.3  |

# %% [markdown]
# ## Cost of indexing

# %%
index_df = pd.read_csv(f'{bench_dir}/index.rocksdb.txt', sep='\t')
index_df[["h:m:s", "s", "max_rss"]]
# Out:
#      h:m:s          s   max_rss
# 0  5:52:02  21122.088  14593.36
