# %%
import sys
sys.prefix
# Out:
# '/home/ctbrown/.conda/envs/jup312'

# %%
#bench_dir = 'benchmarks-2024-10-12.pr-branch-430'
bench_dir = 'benchmarks-2024-06-30.v096'
#bench_dir = 'benchmarks-2024-10-16.v098'

# %%
ls
# Out:
# README.md                                SRR5650070.gather.csv
# SRR12324253.fastgather.csv               SRR5650070.prefetch.csv
# SRR12324253.fastmultigather.csv          SRR5650070.pygather.csv
# SRR12324253.fastmultigather_rocksdb.csv  SRR5650070.trim.sig.zip
# SRR12324253.gather.csv                   SRR606249.fastgather.csv
# SRR12324253.prefetch.csv                 SRR606249.fastmultigather.csv
# SRR12324253.pygather.csv                 SRR606249.fastmultigather_rocksdb.csv
# SRR12324253.trim.sig.zip                 SRR606249.gather.csv
# SRR1976948.fastgather.csv                SRR606249.prefetch.csv
# SRR1976948.fastmultigather.csv           SRR606249.pygather.csv
# SRR1976948.fastmultigather_rocksdb.csv   SRR606249.trim.sig.zip
# SRR1976948.gather.csv                    Snakefile
# SRR1976948.prefetch.csv                  benchmarks-2024-06-30.v096/
# SRR1976948.pygather.csv                  benchmarks-2024-08-25.pr-branch-430/
# SRR1976948.trim.sig.zip                  benchmarks-2024-10-12.pr-branch-430/
# SRR5650070.fastgather.csv                benchmarks-2024-10-16.v098/
# SRR5650070.fastmultigather.csv           gtdb-rs214-k31.rocksdb/
# SRR5650070.fastmultigather_rocksdb.csv   parse.ipynb

# %%
import pandas as pd
import os

# %%
pd.read_csv(f'{bench_dir}/fastmultigather.SRR12324253.txt', sep='\t')
# Out:
#           s    h:m:s   max_rss  max_vms   max_uss   max_pss  io_in  io_out  \
# 0  348.9278  0:05:48  15896.88  24909.7  15924.22  15929.22    0.0    20.7
#
#    mean_load  cpu_time
# 0     940.25    3286.8

# %%
samples = ['SRR12324253', 'SRR1976948', 'SRR5650070', 'SRR606249']
prefixes = [ 'fastmultigather', 'fastmultigather_rocksdb', 'fastgather', 'pygather']

# %%
df_list = []
for s in samples:
    for p in prefixes:
        df = pd.read_csv(f'{bench_dir}/{p}.{s}.txt', sep='\t')
        df.insert(0, "prefix", [p], True)
        df.insert(1, "sample", [s], True)
        df_list.append(df)

df = pd.concat(df_list)

# %%
df
# Out:
#                     prefix       sample          s    h:m:s   max_rss  \
# 0          fastmultigather  SRR12324253   348.9278  0:05:48  15896.88
# 0  fastmultigather_rocksdb  SRR12324253   150.5767  0:02:30   1237.51
# 0               fastgather  SRR12324253    85.9894  0:01:25  15125.80
# 0                 pygather  SRR12324253  2704.3314  0:45:04  16685.05
# 0          fastmultigather   SRR1976948   441.7485  0:07:21  13029.59
# 0  fastmultigather_rocksdb   SRR1976948   102.1025  0:01:42    515.24
# 0               fastgather   SRR1976948   152.3116  0:02:32  13071.14
# 0                 pygather   SRR1976948  2768.4841  0:46:08  13755.16
# 0          fastmultigather   SRR5650070   286.1431  0:04:46  15017.48
# 0  fastmultigather_rocksdb   SRR5650070    65.8363  0:01:05    725.36
# 0               fastgather   SRR5650070    84.8851  0:01:24   8561.77
# 0                 pygather   SRR5650070  2519.3922  0:41:59  15751.79
# 0          fastmultigather    SRR606249   395.4727  0:06:35  13299.85
# 0  fastmultigather_rocksdb    SRR606249   104.3750  0:01:44    527.95
# 0               fastgather    SRR606249   109.1145  0:01:49  13393.11
# 0                 pygather    SRR606249  2654.5982  0:44:14  14053.35
#
#     max_vms   max_uss   max_pss     io_in  io_out  mean_load  cpu_time
# 0  24909.70  15924.22  15929.22      0.00   20.70     940.25   3286.80
# 0  27831.25   1236.85   1241.55   2377.28    0.00      26.62     49.85
# 0  22418.14   4264.41   4269.11  12004.85    0.01    4931.44   4245.88
# 0  20923.56  16681.90  16686.60  11973.07    0.00      98.75   2683.51
# 0  24910.79  13061.85  13066.88      0.00    5.35    1473.88   6518.03
# 0  27109.97    514.11    518.83    996.23    0.00      27.85     36.73
# 0  20908.50   4249.58   4254.30      3.69    0.06    4708.22   7177.96
# 0  17991.26  13751.92  13756.61  11973.44    0.09      99.95   2775.79
# 0  24907.12  15050.96  15056.00      0.00   16.75    1123.02   3219.42
# 0  27322.44    726.63    731.35    484.39    0.00      36.01     29.08
# 0  21201.91   3376.29   3380.89      2.57    0.05    4688.65   3985.28
# 0  19985.14  15747.51  15752.21  11974.55    0.00      99.10   2505.17
# 0  24910.54  13332.56  13337.54      0.00    6.91    1157.29   4581.40
# 0  27126.03    527.11    531.80   1327.34    0.00      20.99     27.32
# 0  20901.88   4194.26   4198.95      3.69    0.01    3515.99   3844.68
# 0  18289.87  14047.26  14051.89  11973.44    0.00      98.94   2639.39

# %%
df[df['sample'] == "SRR5650070"]
# Out:
#                     prefix      sample          s    h:m:s   max_rss  \
# 0          fastmultigather  SRR5650070   286.1431  0:04:46  15017.48
# 0  fastmultigather_rocksdb  SRR5650070    65.8363  0:01:05    725.36
# 0               fastgather  SRR5650070    84.8851  0:01:24   8561.77
# 0                 pygather  SRR5650070  2519.3922  0:41:59  15751.79
#
#     max_vms   max_uss   max_pss     io_in  io_out  mean_load  cpu_time
# 0  24907.12  15050.96  15056.00      0.00   16.75    1123.02   3219.42
# 0  27322.44    726.63    731.35    484.39    0.00      36.01     29.08
# 0  21201.91   3376.29   3380.89      2.57    0.05    4688.65   3985.28
# 0  19985.14  15747.51  15752.21  11974.55    0.00      99.10   2505.17

# %%
df[df['sample'] == "SRR5650070"][["prefix", "s", "max_rss"]]
# Out:
#                     prefix          s   max_rss
# 0          fastmultigather   286.1431  15017.48
# 0  fastmultigather_rocksdb    65.8363    725.36
# 0               fastgather    84.8851   8561.77
# 0                 pygather  2519.3922  15751.79

# %%
x = df[df['sample'] == "SRR5650070"][["prefix", "s", "max_rss"]]
x.set_index("prefix")
# Out:
#                                  s   max_rss
# prefix
# fastmultigather           286.1431  15017.48
# fastmultigather_rocksdb    65.8363    725.36
# fastgather                 84.8851   8561.77
# pygather                 2519.3922  15751.79

# %%
df2 = df.copy()
df2 = df2.sort_values('s')
df2 = df2.set_index(["sample", "prefix"])
df2 = df2[["s", "max_rss"]]

# %%
df2
# Out:
#                                              s   max_rss
# sample      prefix
# SRR5650070  fastmultigather_rocksdb    65.8363    725.36
#             fastgather                 84.8851   8561.77
# SRR12324253 fastgather                 85.9894  15125.80
# SRR1976948  fastmultigather_rocksdb   102.1025    515.24
# SRR606249   fastmultigather_rocksdb   104.3750    527.95
#             fastgather                109.1145  13393.11
# SRR12324253 fastmultigather_rocksdb   150.5767   1237.51
# SRR1976948  fastgather                152.3116  13071.14
# SRR5650070  fastmultigather           286.1431  15017.48
# SRR12324253 fastmultigather           348.9278  15896.88
# SRR606249   fastmultigather           395.4727  13299.85
# SRR1976948  fastmultigather           441.7485  13029.59
# SRR5650070  pygather                 2519.3922  15751.79
# SRR606249   pygather                 2654.5982  14053.35
# SRR12324253 pygather                 2704.3314  16685.05
# SRR1976948  pygather                 2768.4841  13755.16

# %%
ls
# Out:
# README.md                                SRR5650070.gather.csv
# SRR12324253.fastgather.csv               SRR5650070.prefetch.csv
# SRR12324253.fastmultigather.csv          SRR5650070.pygather.csv
# SRR12324253.fastmultigather_rocksdb.csv  SRR5650070.trim.sig.zip
# SRR12324253.gather.csv                   SRR606249.fastgather.csv
# SRR12324253.prefetch.csv                 SRR606249.fastmultigather.csv
# SRR12324253.pygather.csv                 SRR606249.fastmultigather_rocksdb.csv
# SRR12324253.trim.sig.zip                 SRR606249.gather.csv
# SRR1976948.fastgather.csv                SRR606249.prefetch.csv
# SRR1976948.fastmultigather.csv           SRR606249.pygather.csv
# SRR1976948.fastmultigather_rocksdb.csv   SRR606249.trim.sig.zip
# SRR1976948.gather.csv                    Snakefile
# SRR1976948.prefetch.csv                  benchmarks-2024-06-30.v096/
# SRR1976948.pygather.csv                  benchmarks-2024-08-25.pr-branch-430/
# SRR1976948.trim.sig.zip                  benchmarks-2024-10-12.pr-branch-430/
# SRR5650070.fastgather.csv                benchmarks-2024-10-16.v098/
# SRR5650070.fastmultigather.csv           gtdb-rs214-k31.rocksdb/
# SRR5650070.fastmultigather_rocksdb.csv   parse.ipynb

# %%
df_by_second = df[df["sample"] == 'SRR1976948'][["prefix", "s", "max_rss"]].sort_values(by="s")
df_by_second.set_index("prefix", inplace=True)
df_by_second
# Out:
#                                  s   max_rss
# prefix
# fastmultigather_rocksdb   102.1025    515.24
# fastgather                152.3116  13071.14
# fastmultigather           441.7485  13029.59
# pygather                 2768.4841  13755.16

# %%
print(df_by_second.to_markdown())
# Out:
# | prefix                  |        s |   max_rss |
# |:------------------------|---------:|----------:|
# | fastmultigather_rocksdb |  102.103 |    515.24 |
# | fastgather              |  152.312 |  13071.1  |
# | fastmultigather         |  441.748 |  13029.6  |
# | pygather                | 2768.48  |  13755.2  |

# %% [markdown]
# ## Cost of indexing

# %%
index_df = pd.read_csv(f'{bench_dir}/index.rocksdb.txt', sep='\t')
index_df[["h:m:s", "s", "max_rss"]]
# Out:
#      h:m:s           s   max_rss
# 0  4:47:34  17254.8469  14042.86
